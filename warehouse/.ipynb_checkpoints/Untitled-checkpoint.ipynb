# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction import DictVectorizer

# %%
df = pd.read_csv('result.csv')
df
# Out:
#      first_name       last_name             full_name last_name_group  gender
# 0         Quỳnh  Nguyễn Thị Như  Nguyễn Thị Như Quỳnh          Nguyễn     NaN
# 1          Quân        Lê Hoàng         Lê Hoàng Quân              Lê     NaN
# 2        Phượng        Đinh Văn       Đinh Văn Phượng            Đinh     NaN
# 3        Samuel    Nguyễn Echam   Nguyễn Echam Samuel          Nguyễn     NaN
# 4          Sang     Nguyễn Xuân      Nguyễn Xuân Sang          Nguyễn     NaN
# ...         ...             ...                   ...             ...     ...
# 8752        Thi        Lê Thiên          Lê Thiên Thi              Lê     NaN
# 8753      Thành        Phan Tấn        Phan Tấn Thành            Phan     NaN
# 8754      Thành      Nguyễn Thế      Nguyễn Thế Thành          Nguyễn     NaN
# 8755      Thanh   Trần Thành Vi   Trần Thành Vi Thanh            Trần     NaN
# 8756       Thảo     Nguyễn Mạnh      Nguyễn Mạnh Thảo          Nguyễn     NaN
#
# [8757 rows x 5 columns]

# %%
import random

gender1 = ['F','M']
df['gender'] = np.random.choice(gender1, df.shape[0])

# %%
df
# Out:
#      first_name       last_name             full_name last_name_group gender
# 0         Quỳnh  Nguyễn Thị Như  Nguyễn Thị Như Quỳnh          Nguyễn      F
# 1          Quân        Lê Hoàng         Lê Hoàng Quân              Lê      M
# 2        Phượng        Đinh Văn       Đinh Văn Phượng            Đinh      F
# 3        Samuel    Nguyễn Echam   Nguyễn Echam Samuel          Nguyễn      F
# 4          Sang     Nguyễn Xuân      Nguyễn Xuân Sang          Nguyễn      M
# ...         ...             ...                   ...             ...    ...
# 8752        Thi        Lê Thiên          Lê Thiên Thi              Lê      F
# 8753      Thành        Phan Tấn        Phan Tấn Thành            Phan      F
# 8754      Thành      Nguyễn Thế      Nguyễn Thế Thành          Nguyễn      F
# 8755      Thanh   Trần Thành Vi   Trần Thành Vi Thanh            Trần      F
# 8756       Thảo     Nguyễn Mạnh      Nguyễn Mạnh Thảo          Nguyễn      M
#
# [8757 rows x 5 columns]

# %%
df.drop(['last_name', 'last_name_group','first_name'], axis=1, inplace=True)

# %%
df
# Out:
#      last_name_group gender
# 0             Nguyễn      F
# 1                 Lê      M
# 2               Đinh      F
# 3             Nguyễn      F
# 4             Nguyễn      M
# ...              ...    ...
# 8752              Lê      F
# 8753            Phan      F
# 8754          Nguyễn      F
# 8755            Trần      F
# 8756          Nguyễn      M
#
# [8757 rows x 2 columns]

# %%
df_names = df

# %%
df_names.gender.replace({'F':0,'M':1},inplace=True)

# %%
df_names.gender.unique()
# Out:
# array([1, 0])

# %%
df_names.dtypes
# Out:
# first_name    object
# gender         int64
# dtype: object

# %%
Xfeatures =df_names['first_name']

# %%
cv = CountVectorizer()
X = cv.fit_transform(Xfeatures)

# %%
cv.get_feature_names()
# Out:
# /home/longvudang/.local/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['adrơng',
#  'ai',
#  'an',
#  'anh',
#  'ayun',
#  'ba',
#  'ban',
#  'baïn',
#  'baûo',
#  'binh',
#  'biên',
#  'biển',
#  'bàng',
#  'bào',
#  'bá',
#  'bác',
#  'bách',
#  'báşąng',
#  'bão',
#  'bä',
#  'bé',
#  'bình',
#  'bích',
#  'bông',
#  'böûu',
#  'bạch',
#  'bạo',
#  'bảo',
#  'bảy',
#  'bắc',
#  'bằng',
#  'bốn',
#  'bồng',
#  'bộ',
#  'bửu',
#  'ca',
#  'can',
#  'cang',
#  'cao',
#  'chaún',
#  'chi',
#  'chinh',
#  'chiên',
#  'chiêu',
#  'chiến',
#  'chiểu',
#  'chung',
#  'chuyên',
#  'chuyền',
#  'chuẩn',
#  'chánh',
#  'chân',
#  'châu',
#  'chình',
#  'chí',
#  'chính',
#  'chăm',
#  'chư',
#  'chương',
#  'chất',
#  'chỉnh',
#  'chức',
#  'cát',
#  'cân',
#  'công',
#  'cöôøng',
#  'cúc',
#  'cơ',
#  'cương',
#  'cường',
#  'cảnh',
#  'cấp',
#  'cần',
#  'cầu',
#  'cẩm',
#  'cẩn',
#  'cừ',
#  'cửu',
#  'cự',
#  'danh',
#  'di',
#  'dieäu',
#  'dieåm',
#  'dinh',
#  'diễm',
#  'diện',
#  'diệp',
#  'diệu',
#  'do',
#  'doanh',
#  'dona',
#  'du',
#  'dung',
#  'duy',
#  'duyên',
#  'duyệt',
#  'duân',
#  'duõng',
#  'duẫn',
#  'dy',
#  'dân',
#  'dö',
#  'döông',
#  'dĩnh',
#  'dũ',
#  'dũng',
#  'dư',
#  'dương',
#  'dưỡng',
#  'dạng',
#  'dậu',
#  'dềng',
#  'dụng',
#  'dững',
#  'dự',
#  'em',
#  'gia',
#  'giang',
#  'giao',
#  'giaõ',
#  'giaøu',
#  'giàu',
#  'giáp',
#  'giảng',
#  'giới',
#  'gẩm',
#  'hai',
#  'hanh',
#  'haäu',
#  'hi',
#  'hieàn',
#  'hinh',
#  'hitachi',
#  'hiáť',
#  'hiên',
#  'hiến',
#  'hiếu',
#  'hiền',
#  'hiển',
#  'hiệp',
#  'hiệu',
#  'hoa',
#  'hoan',
#  'hoaønh',
#  'hoà',
#  'hoài',
#  'hoàn',
#  'hoàng',
#  'hoành',
#  'hoá',
#  'hoøa',
#  'hoạch',
#  'hoạt',
#  'huy',
#  'huynh',
#  'huyên',
#  'huyền',
#  'huân',
#  'huøng',
#  'huấn',
#  'huần',
#  'huệ',
#  'huỳnh',
#  'hwing',
#  'hy',
#  'hà',
#  'hài',
#  'hàm',
#  'hàng',
#  'hành',
#  'hào',
#  'háş',
#  'háť',
#  'hân',
#  'hãn',
#  'hình',
#  'hòa',
#  'hóa',
#  'hông',
#  'höõu',
#  'hùng',
#  'hć',
#  'hư',
#  'hưng',
#  'hương',
#  'hướng',
#  'hường',
#  'hưởng',
#  'hạ',
#  'hạc',
#  'hạnh',
#  'hạo',
#  'hải',
#  'hảo',
#  'hận',
#  'hậu',
#  'hằng',
#  'hệ',
#  'học',
#  'hồi',
#  'hồng',
#  'hổ',
#  'hội',
#  'hớn',
#  'hởi',
#  'hợi',
#  'hợp',
#  'hữu',
#  'hỷ',
#  'kachu',
#  'kbuôr',
#  'keng',
#  'kha',
#  'khang',
#  'khanh',
#  'khaùnh',
#  'khiêm',
#  'khiết',
#  'khiếu',
#  'khiển',
#  'khoa',
#  'khoài',
#  'khoái',
#  'khoát',
#  'khoâi',
#  'khoẻ',
#  'khueâ',
#  'khuyên',
#  'khuyến',
#  'khuê',
#  'khánh',
#  'khôi',
#  'khôn',
#  'khương',
#  'khả',
#  'khải',
#  'khởi',
#  'kieàu',
#  'kieân',
#  'kim',
#  'kin',
#  'kiêm',
#  'kiên',
#  'kiếm',
#  'kiều',
#  'kiển',
#  'kiện',
#  'kiệt',
#  'ktla',
#  'kê',
#  'kông',
#  'kế',
#  'kết',
#  'kỳ',
#  'kỵ',
#  'kỷ',
#  'la',
#  'lai',
#  'lam',
#  'lan',
#  'lang',
#  'lanh',
#  'lay',
#  'laâm',
#  'laäp',
#  'laøo',
#  'lieân',
#  'lil',
#  'lin',
#  'linh',
#  'liêm',
#  'liên',
#  'liền',
#  'liễu',
#  'loan',
#  'long',
#  'luaân',
#  'luyến',
#  'luyện',
#  'luân',
#  'luận',
#  'luật',
#  'ly',
#  'lài',
#  'lành',
#  'lâm',
#  'lân',
#  'lã',
#  'lãm',
#  'lê',
#  'lên',
#  'löïc',
#  'löông',
#  'löûa',
#  'lý',
#  'lăng',
#  'lĩnh',
#  'lũng',
#  'lưu',
#  'lương',
#  'lưỡng',
#  'lượng',
#  'lại',
#  'lập',
#  'lẹ',
#  'lễ',
#  'lệ',
#  'lịch',
#  'lịnh',
#  'lỗi',
#  'lộc',
#  'lợi',
#  'lục',
#  'lừng',
#  'lữ',
#  'lực',
#  'mai',
#  'maïnh',
#  'mi',
#  'minh',
#  'miên',
#  'my',
#  'myõ',
#  'mãn',
#  'mùi',
#  'mười',
#  'mạnh',
#  'mảnh',
#  'mẩn',
#  'mẫn',
#  'mận',
#  'mến',
#  'mỉnh',
#  'mộng',
#  'một',
#  'mừng',
#  'mỹ',
#  'na',
#  'nam',
#  'ng',
#  'nga',
#  'ngaân',
#  'nghi',
#  'nghiêm',
#  'nghiệp',
#  'nghò',
#  'nghóa',
#  'nghĩa',
#  'nghệ',
#  'nghị',
#  'nghịch',
#  'ngoan',
#  'ngon',
#  'nguyeân',
#  'nguyeän',
#  'nguyên',
#  'nguyễn',
#  'nguyện',
#  'nguyệt',
#  'ngà',
#  'ngàn',
#  'ngân',
#  'ngôn',
#  'ngọ',
#  'ngọc',
#  'ngộ',
#  'ngữ',
#  'ngự',
#  'nh',
#  'nha',
#  'nhanh',
#  'nhaân',
#  'nhi',
#  'nhiên',
#  'nhiều',
#  'nhiệm',
#  'nhu',
#  'nhung',
#  'nhuân',
#  'nhuần',
#  'nhuận',
#  'nhàn',
#  'nhâm',
#  'nhân',
#  'nhã',
#  'nhãn',
#  'nhơn',
#  'như',
#  'nhường',
#  'nhưỡng',
#  'nhạn',
#  'nhả',
#  'nhất',
#  'nhẫn',
#  'nhật',
#  'nhớ',
#  'nhờ',
#  'nhứt',
#  'nhựt',
#  'ni',
#  'ninh',
#  'niê',
#  'niệm',
#  'ny',
#  'nào',
#  'nèo',
#  'nên',
#  'nông',
#  'núi',
#  'năng',
#  'nưng',
#  'nương',
#  'nội',
#  'oai',
#  'oanh',
#  'pha',
#  'phan',
#  'phi',
#  'phiên',
#  'phiệt',
#  'phong',
#  'phuïc',
#  'pháp',
#  'phát',
#  'phù',
#  'phùc',
#  'phùng',
#  'phú',
#  'phúc',
#  'phć',
#  'phương',
#  'phước',
#  'phượng',
#  'phục',
#  'phụng',
#  'phứơc',
#  'ponl',
#  'pích',
#  'pô',
#  'qua',
#  'quan',
#  'quang',
#  'quaân',
#  'qui',
#  'quy',
#  'quyên',
#  'quyến',
#  'quyết',
#  'quyền',
#  'quân',
#  'quí',
#  'quý',
#  'quả',
#  'quảng',
#  'quất',
#  'quế',
#  'quốc',
#  'quỳnh',
#  'qúi',
#  'qúy',
#  'rinh',
#  'riếp',
#  'ru',
#  'rôn',
#  'rồng',
#  'sa',
#  'samuel',
#  'san',
#  'sang',
#  'sanh',
#  'saét',
#  'sen',
#  'sinh',
#  'song',
#  'soái',
#  'soát',
#  'student',
#  'sung',
#  'sáng',
#  'sáu',
#  'sâm',
#  'só',
#  'sôn',
#  'sĩ',
#  'sơn',
#  'sương',
#  'sầu',
#  'sứ',
#  'sứng',
#  'sử',
#  'sự',
#  'sỹ',
#  'tam',
#  'taâm',
#  'taân',
#  'teøo',
#  'thang',
#  'thanh',
#  'thao',
#  'thaéng',
#  'thaûo',
#  'thi',
#  'thinh',
#  'thiêm',
#  'thiên',
#  'thiết',
#  'thiều',
#  'thiện',
#  'thiệp',
#  'thiệt',
#  'thiệu',
#  'tho',
#  'thoa',
#  'thoan',
#  'thoïai',
#  'thoại',
#  'thoảng',
#  'thu',
#  'thuyên',
#  'thuyết',
#  'thuyền',
#  'thuân',
#  'thuý',
#  'thuấn',
#  'thuần',
#  'thuận',
#  'thuật',
#  'thuỳ',
#  'thuỷ',
#  'thy',
#  'thành',
#  'thào',
#  'thái',
#  'thám',
#  'tháp',
#  'tháşąch',
#  'tháşło',
#  'thân',
#  'thìn',
#  'thôn',
#  'thông',
#  'thö',
#  'thöông',
#  'thùy',
#  'thú',
#  'thúy',
#  'thă',
#  'thăng',
#  'thơ',
#  'thơm',
#  'thư',
#  'thương',
#  'thường',
#  'thưởng',
#  'thượng',
#  'thạch',
#  'thạnh',
#  'thạo',
#  'thảo',
#  'thầm',
#  'thắm',
#  'thắng',
#  'thặng',
#  'thế',
#  'thể',
#  'thịnh',
#  'thọ',
#  'thỏa',
#  'thống',
#  'thổ',
#  'thời',
#  'thụ',
#  'thục',
#  'thụy',
#  'thủ',
#  'thủy',
#  'thứ',
#  'thức',
#  'thừa',
#  'thực',
#  'tin',
#  'tiên',
#  'tiến',
#  'tiền',
#  'tiệp',
#  'toan',
#  'toàn',
#  'toán',
#  'toă',
#  'toại',
#  'toản',
#  'trai',
#  'trang',
#  'tri',
#  'trieàu',
#  'trinh',
#  'triết',
#  'triều',
#  'triễn',
#  'triệu',
#  'trong',
#  'trung',
#  'truyên',
#  'truyền',
#  'truùc',
#  'truờng',
#  'trà',
#  'trác',
#  'tráng',
#  'trâm',
#  'trân',
#  'trình',
#  'trí',
#  'trúc',
#  'trưng',
#  'trương',
#  'trường',
#  'trưởng',
#  'trạng',
#  'trắng',
#  'trị',
#  'trịnh',
#  'trọng',
#  'trứ',
#  'trữ',
#  'trực',
#  'tu',
#  'tuaán',
#  'tuaân',
#  'tuy',
#  'tuyeån',
#  'tuyên',
#  'tuyến',
#  'tuyết',
#  'tuyền',
#  'tuyển',
#  'tuyễn',
#  'tuân',
#  'tuấn',
#  'tuất',
#  'ty',
#  'tài',
#  'tá',
#  'tám',
#  'tánh',
#  'táť',
#  'tâm',
#  'tân',
#  'tây',
#  'tình',
#  'tín',
#  'tính',
#  'tòng',
#  'tôn',
#  'töôøng',
#  'töù',
#  'tùng',
#  'tú',
#  'túc',
#  'tý',
#  'tă',
#  'tăng',
#  'tăş',
#  'tĩnh',
#  'tư',
#  'tước',
#  'tường',
#  'tưởng',
#  'tạo',
#  'tấn',
#  'tất',
#  'tần',
#  'tầy',
#  'tẩm',
#  'tẩn',
#  'tỉnh',
#  'tịnh',
#  'tới',
#  'tự',
#  'tỵ',
#  'uy',
#  'uyên',
#  'uùt',
#  'vi',
#  'vieät',
#  'vin',
#  'vinh',
#  'viên',
#  'viển',
#  'viễn',
#  'việt',
#  'vui',
#  'vuõ',
#  'vy',
#  'vàng',
#  'vân',
#  'võ',
#  'văn',
#  'vĩ',
#  'vĩnh',
#  'vũ',
#  'vươn',
#  'vương',
#  'vượng',
#  'vạn',
#  'vấn',
#  'vẵn',
#  'vỉnh',
#  'vị',
#  'vọng',
#  'vụ',
#  'vỹ',
#  'xoan',
#  'xuyên',
#  'xuyến',
#  'xuân',
#  'xí',
#  'xứng',
#  'yêm',
#  'yên',
#  'yù',
#  'yến',
#  'ái',
#  'ánh',
#  'áť',
#  'ân',
#  'âu',
#  'êban',
#  'ñoàng',
#  'ñoä',
#  'út',
#  'úy',
#  'đa',
#  'đal',
#  'đan',
#  'đang',
#  'điềm',
#  'điền',
#  'điều',
#  'điển',
#  'điệp',
#  'điệu',
#  'đoan',
#  'đoàn',
#  'đào',
#  'đình',
#  'đích',
#  'đô',
#  'đôn',
#  'đông',
#  'đăng',
#  'đường',
#  'được',
#  'đượm',
#  'đại',
#  'đạo',
#  'đạt',
#  'đảm',
#  'đảng',
#  'đảo',
#  'đầy',
#  'đẩu',
#  'đắc',
#  'đẳng',
#  'đặng',
#  'đến',
#  'định',
#  'đỏ',
#  'đồng',
#  'độ',
#  'đời',
#  'đủ',
#  'đức',
#  'ưng',
#  'ước',
#  'ảnh',
#  'ấn',
#  'ấng',
#  'ất',
#  'ẩn']

# %%
genderpredictor('sương')
# Out:
# Female

# %%
print("Accuracy of Model",clf.score(X_test,y_test)*100,"%")
# Out:
# Accuracy of Model 49.42922374429224 %

# %%
print("Accuracy of Model",clf.score(X_train,y_train)*100,"%")
# Out:
# Accuracy of Model 59.44325481798715 %

# %%
def features(name):
    name = name.lower()
    return {
        'first-letter': name[0], # First letter
        'first2-letters': name[0:2], # First 2 letters
        'first3-letters': name[0:3], # First 3 letters
        'last-letter': name[-1],
        'last2-letters': name[-2:],
        'last3-letters': name[-3:],
    }

# %%
features = np.vectorize(features)
print(features(["Long", "Đạt", "Tiên","Toàn","Ngọc"]))
# Out:
# [{'first-letter': 'l', 'first2-letters': 'lo', 'first3-letters': 'lon', 'last-letter': 'g', 'last2-letters': 'ng', 'last3-letters': 'ong'}
#  {'first-letter': 'đ', 'first2-letters': 'đạ', 'first3-letters': 'đạt', 'last-letter': 't', 'last2-letters': 'ạt', 'last3-letters': 'đạt'}
#  {'first-letter': 't', 'first2-letters': 'ti', 'first3-letters': 'tiê', 'last-letter': 'n', 'last2-letters': 'ên', 'last3-letters': 'iên'}
#  {'first-letter': 't', 'first2-letters': 'to', 'first3-letters': 'toà', 'last-letter': 'n', 'last2-letters': 'àn', 'last3-letters': 'oàn'}
#  {'first-letter': 'n', 'first2-letters': 'ng', 'first3-letters': 'ngọ', 'last-letter': 'c', 'last2-letters': 'ọc', 'last3-letters': 'gọc'}]

# %%
df_X = features(df_names['first_name'])
df_y = df_names['gender']

# %%
from sklearn.feature_extraction import DictVectorizer
 
corpus = features(["Long", "Nga"])
dv = DictVectorizer()
dv.fit(corpus)
transformed = dv.transform(corpus)
print(transformed)
# Out:
#   (0, 0)	1.0
#   (0, 2)	1.0
#   (0, 4)	1.0
#   (0, 7)	1.0
#   (0, 9)	1.0
#   (0, 11)	1.0
#   (1, 1)	1.0
#   (1, 3)	1.0
#   (1, 5)	1.0
#   (1, 6)	1.0
#   (1, 8)	1.0
#   (1, 10)	1.0

# %%
dv.get_feature_names()
# Out:
# /home/longvudang/.local/lib/python3.8/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['first-letter=l',
#  'first-letter=n',
#  'first2-letters=lo',
#  'first2-letters=ng',
#  'first3-letters=lon',
#  'first3-letters=nga',
#  'last-letter=a',
#  'last-letter=g',
#  'last2-letters=ga',
#  'last2-letters=ng',
#  'last3-letters=nga',
#  'last3-letters=ong']

# %%
dfX_train, dfX_test, dfy_train, dfy_test = train_test_split(df_X, df_y, test_size=0.33, random_state=42)

# %%
dv = DictVectorizer()
dv.fit_transform(dfX_train)
# Out:
# <5867x1542 sparse matrix of type '<class 'numpy.float64'>'
# 	with 35202 stored elements in Compressed Sparse Row format>

# %%
from sklearn.tree import DecisionTreeClassifier
 
dclf = DecisionTreeClassifier()
my_xfeatures =dv.transform(dfX_train)
dclf.fit(my_xfeatures, dfy_train)
# Out:
# DecisionTreeClassifier()

# %%
sample_name_eg = ["Đạt"]
transform_dv =dv.transform(features(sample_name_eg))

# %%
vect3 = transform_dv.toarray()

# %%
dclf.predict(vect3)
# Out:
# array([1])

# %%
if dclf.predict(vect3) == 0:
    print("Female")
else:
    print("Male")
# Out:
# Male

# %%
def genderpredictor1(a):
    test_name1 = [a]
    transform_dv =dv.transform(features(test_name1))
    vector = transform_dv.toarray()
    if dclf.predict(vector) == 0:
        print("Female")
    else:
        print("Male")

# %%
random_name_list = ["Minh","Duy","Khoa","Hồng","Quang","Hiển"]

# %%
for n in random_name_list:
    print(genderpredictor1(n))
# Out:
# Male
# None
# Female
# None
# Female
# None
# Female
# None
# Female
# None
# Female
# None

# %%
print(dclf.score(dv.transform(dfX_train), dfy_train))
# Out:
# 0.6057610363047554

# %%
print(dclf.score(dv.transform(dfX_test), dfy_test))
# Out:
# 0.4972318339100346
